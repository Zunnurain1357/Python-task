# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/samsung/Documents/pizz_data.csv")

df
# Out:
#        order_id        date      time  order_details_id  order_id.1  \
# 0           1.0  2015-01-01  11:38:36                 1           1
# 1           2.0  2015-01-01  11:57:40                 2           2
# 2           3.0  2015-01-01  12:12:28                 3           2
# 3           4.0  2015-01-01  12:16:31                 4           2
# 4           5.0  2015-01-01  12:21:30                 5           2
# ...         ...         ...       ...               ...         ...
# 48615       NaN         NaN       NaN             48616       21348
# 48616       NaN         NaN       NaN             48617       21348
# 48617       NaN         NaN       NaN             48618       21348
# 48618       NaN         NaN       NaN             48619       21349
# 48619       NaN         NaN       NaN             48620       21350
#
#             pizza_id  quantity  pizza_id.1 pizza_type_id size  price  \
# 0         hawaiian_m         1   bbq_ckn_s       bbq_ckn    S  12.75
# ...

# %%
df.head()
# Out:
#    order_id        date      time  order_details_id  order_id.1  \
# 0       1.0  2015-01-01  11:38:36                 1           1
# 1       2.0  2015-01-01  11:57:40                 2           2
# 2       3.0  2015-01-01  12:12:28                 3           2
# 3       4.0  2015-01-01  12:16:31                 4           2
# 4       5.0  2015-01-01  12:21:30                 5           2
#
#         pizza_id  quantity  pizza_id.1 pizza_type_id size  price  \
# 0     hawaiian_m         1   bbq_ckn_s       bbq_ckn    S  12.75
# 1  classic_dlx_m         1   bbq_ckn_m       bbq_ckn    M  16.75
# 2  five_cheese_l         1   bbq_ckn_l       bbq_ckn    L  20.75
# 3    ital_supr_l         1  cali_ckn_s      cali_ckn    S  12.75
# 4     mexicana_m         1  cali_ckn_m      cali_ckn    M  16.75
#
#   pizza_type_id.1                          name category  \
# 0         bbq_ckn    The Barbecue Chicken Pizza  Chicken
# 1        cali_ckn  The California Chicken Pizza  Chicken
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          21350 non-null  float64
#  1   date              21350 non-null  object
#  2   time              21350 non-null  object
#  3   order_details_id  48620 non-null  int64
#  4   order_id.1        48620 non-null  int64
#  5   pizza_id          48620 non-null  object
#  6   quantity          48620 non-null  int64
#  7   pizza_id.1        96 non-null     object
#  8   pizza_type_id     96 non-null     object
#  9   size              96 non-null     object
#  10  price             96 non-null     float64
#  11  pizza_type_id.1   32 non-null     object
#  12  name              32 non-null     object
#  13  category          32 non-null     object
#  14  ingredients       32 non-null     object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 5.6+ MB

# %%
df.isna().sum()
# Out:
# order_id            27270
# date                27270
# time                27270
# order_details_id        0
# order_id.1              0
# pizza_id                0
# quantity                0
# pizza_id.1          48524
# pizza_type_id       48524
# size                48524
# price               48524
# pizza_type_id.1     48588
# name                48588
# category            48588
# ingredients         48588
# dtype: int64

# %%
df.head()
# Out:
#    order_id        date      time  order_details_id  order_id.1  \
# 0       1.0  2015-01-01  11:38:36                 1           1
# 1       2.0  2015-01-01  11:57:40                 2           2
# 2       3.0  2015-01-01  12:12:28                 3           2
# 3       4.0  2015-01-01  12:16:31                 4           2
# 4       5.0  2015-01-01  12:21:30                 5           2
#
#         pizza_id  quantity  pizza_id.1 pizza_type_id size  price  \
# 0     hawaiian_m         1   bbq_ckn_s       bbq_ckn    S  12.75
# 1  classic_dlx_m         1   bbq_ckn_m       bbq_ckn    M  16.75
# 2  five_cheese_l         1   bbq_ckn_l       bbq_ckn    L  20.75
# 3    ital_supr_l         1  cali_ckn_s      cali_ckn    S  12.75
# 4     mexicana_m         1  cali_ckn_m      cali_ckn    M  16.75
#
#   pizza_type_id.1                          name category  \
# 0         bbq_ckn    The Barbecue Chicken Pizza  Chicken
# 1        cali_ckn  The California Chicken Pizza  Chicken
# ...

# %%
df.drop(columns=['pizza_type_id.1','pizza_id.1','order_id.1'], inplace=True)

# %%
df.isna().sum()
# Out:
# order_id            27270
# date                27270
# time                27270
# order_details_id        0
# order_id.1              0
# pizza_id                0
# quantity                0
# pizza_id.1          48524
# pizza_type_id       48524
# size                48524
# price               48524
# pizza_type_id.1     48588
# name                48588
# category            48588
# ingredients         48588
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          21350 non-null  object
#  1   date              21350 non-null  object
#  2   time              21350 non-null  object
#  3   order_details_id  48620 non-null  object
#  4   order_id.1        48620 non-null  object
#  5   pizza_id          48620 non-null  object
#  6   quantity          48620 non-null  object
#  7   pizza_id.1        96 non-null     object
#  8   pizza_type_id     96 non-null     object
#  9   size              96 non-null     object
#  10  price             96 non-null     object
#  11  pizza_type_id.1   32 non-null     object
#  12  name              32 non-null     object
#  13  category          32 non-null     object
#  14  ingredients       32 non-null     object
# dtypes: object(15)
# memory usage: 5.6+ MB

# %%
df.head()
# Out:
#   order_id        date      time order_details_id       pizza_id quantity  \
# 0      1.0  2015-01-01  11:38:36                1     hawaiian_m        1
# 1      2.0  2015-01-01  11:57:40                2  classic_dlx_m        1
# 2      3.0  2015-01-01  12:12:28                3  five_cheese_l        1
# 3      4.0  2015-01-01  12:16:31                4    ital_supr_l        1
# 4      5.0  2015-01-01  12:21:30                5     mexicana_m        1
#
#   pizza_type_id size  price                          name category  \
# 0       bbq_ckn    S  12.75    The Barbecue Chicken Pizza  Chicken
# 1       bbq_ckn    M  16.75  The California Chicken Pizza  Chicken
# 2       bbq_ckn    L  20.75     The Chicken Alfredo Pizza  Chicken
# 3      cali_ckn    S  12.75       The Chicken Pesto Pizza  Chicken
# 4      cali_ckn    M  16.75   The Southwest Chicken Pizza  Chicken
#
#                                          ingredients
# 0  Barbecued Chicken, Red Peppers, Green Peppers,...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          21350 non-null  object
#  1   date              21350 non-null  object
#  2   time              21350 non-null  object
#  3   order_details_id  48620 non-null  object
#  4   pizza_id          48620 non-null  object
#  5   quantity          48620 non-null  object
#  6   pizza_type_id     96 non-null     object
#  7   size              96 non-null     object
#  8   price             96 non-null     object
#  9   name              32 non-null     object
#  10  category          32 non-null     object
#  11  ingredients       32 non-null     object
# dtypes: object(12)
# memory usage: 4.5+ MB

# %%
df.isna().sum()
# Out:
# order_id            27270
# date                27270
# time                27270
# order_details_id        0
# pizza_id                0
# quantity                0
# pizza_type_id       48524
# size                48524
# price               48524
# name                48588
# category            48588
# ingredients         48588
# dtype: int64

# %%
df.isna().sum()
# Out:
# order_id                0
# date                27270
# time                27270
# order_details_id        0
# pizza_id                0
# quantity                0
# pizza_type_id           0
# size                    0
# price                   0
# name                    0
# category                0
# ingredients             0
# dtype: int64

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["time"] = pd.to_datetime(df["time"])

# %%
df['quantity'] = pd.to_numeric(df["quantity"], errors = 'coerce').fillna(0)

# %%
df['sales'] = pd.to_numeric(df["sales"], errors = 'coerce').fillna(0)

# %%
df.isna().sum()
# Out:
# order_id                0
# date                27270
# time                27270
# order_details_id        0
# pizza_id                0
# quantity                0
# pizza_type_id           0
# size                    0
# price                   0
# name                    0
# category                0
# ingredients             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          48620 non-null  object
#  1   date              21350 non-null  datetime64[ns]
#  2   time              21350 non-null  datetime64[ns]
#  3   order_details_id  48620 non-null  object
#  4   pizza_id          48620 non-null  object
#  5   quantity          48620 non-null  int64
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  object
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 4.5+ MB

# %%
df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          48620 non-null  object
#  1   date              21350 non-null  datetime64[ns]
#  2   time              21350 non-null  datetime64[ns]
#  3   order_details_id  48620 non-null  object
#  4   pizza_id          48620 non-null  object
#  5   quantity          48620 non-null  int64
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             96 non-null     float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(8)
# memory usage: 4.5+ MB

# %% [markdown]
# ### 1
# ##Total revenue/sales

# %%
## to calculate the revenue 
df['revenue'] = df['price'] * df['quantity']

df
# Out:
#        order_id       date                time order_details_id  \
# 0           1.0 2015-01-01 2025-05-12 11:38:36                1
# 1           2.0 2015-01-01 2025-05-12 11:57:40                2
# 2           3.0 2015-01-01 2025-05-12 12:12:28                3
# 3           4.0 2015-01-01 2025-05-12 12:16:31                4
# 4           5.0 2015-01-01 2025-05-12 12:21:30                5
# ...         ...        ...                 ...              ...
# 48615  order_id        NaT                 NaT            48616
# 48616  order_id        NaT                 NaT            48617
# 48617  order_id        NaT                 NaT            48618
# 48618  order_id        NaT                 NaT            48619
# 48619  order_id        NaT                 NaT            48620
#
#             pizza_id  quantity  pizza_type_id  size  price  \
# 0         hawaiian_m         1        bbq_ckn     S  12.75
# 1      classic_dlx_m         1        bbq_ckn     M  16.75
# ...

# %%
### total revenueT
Total_revenue = df["revenue"].sum()

Total_revenue
# Out:
# 1590.8

# %% [markdown]
# ### 2
# ## Total quantity sold

# %%
total_quantity_sold = df["quantity"].sum()

total_quantity_sold
# Out:
# 49574

# %% [markdown]
# ### 3
# ## Total Orders

# %%
df["order_id"].value_counts()
# Out:
# order_id
# <bound method Series.reset_index of 0        <bound method Series.reset_index of 0         ...\n1        <bound method Series.reset_index of 0         ...\n2        <bound method Series.reset_index of 0         ...\n3        <bound method Series.reset_index of 0         ...\n4        <bound method Series.reset_index of 0         ...\n                               ...                        \n48615    <bound method Series.reset_index of 0         ...\n48616    <bound method Series.reset_index of 0         ...\n48617    <bound method Series.reset_index of 0         ...\n48618    <bound method Series.reset_index of 0         ...\n48619    <bound method Series.reset_index of 0         ...\nName: order_id, Length: 48620, dtype: object>    48620
# Name: count, dtype: int64

# %%
df["order_details_id"].value_counts().reset_index()
# Out:
#        order_details_id  count
# 0                     1      1
# 1                 32418      1
# 2                 32409      1
# 3                 32410      1
# 4                 32411      1
# ...                 ...    ...
# 48615             16209      1
# 48616             16210      1
# 48617             16211      1
# 48618             16212      1
# 48619             48620      1
#
# [48620 rows x 2 columns]

# %%
total_orders = len(df['order_id'])

# %%
total_orders
# Out:
# 48620

# %% [markdown]
# ### 3
# ### pizza types

# %%
df["name"].value_counts().reset_index()
# Out:
#                                           name  count
# 0                                         name  48588
# 1                      The Pepper Salami Pizza      1
# 2            The Vegetables + Vegetables Pizza      1
# 3                   The Spinach and Feta Pizza      1
# 4                      The Spinach Pesto Pizza      1
# 5                           The Mexicana Pizza      1
# 6                      The Mediterranean Pizza      1
# 7                 The Italian Vegetables Pizza      1
# 8                       The Green Garden Pizza      1
# 9                        The Four Cheese Pizza      1
# 10                       The Five Cheese Pizza      1
# 11                   The Spinach Supreme Pizza      1
# 12                     The Spicy Italian Pizza      1
# 13                       The Soppressata Pizza      1
# 14                          The Sicilian Pizza      1
# 15            The Prosciutto and Arugula Pizza      1
# ...

# %% [markdown]
# ### 5
# ## Average price of the pizzas

# %%
max_price = df['price'].max()

max_price
# Out:
# 35.95

# %%
average_price = df["price"].mean()


average_price
# Out:
# 16.440625

# %%
min_price = df['price'].min()

min_price
# Out:
# 9.75

# %%
max_price = df['price'].max()

max_price
# Out:
# 35.95

# %%
min_price = df['price'].min()

min_price
# Out:
# 9.75

# %% [markdown]
# ### 6
# ### peak hours of sales

# %%
df['sales'] = df['quantity'] * df['price']
df['sales']
# Out:
# 0        12.75
# 1        16.75
# 2        20.75
# 3        12.75
# 4        16.75
#          ...
# 48615      NaN
# 48616      NaN
# 48617      NaN
# 48618      NaN
# 48619      NaN
# Name: sales, Length: 48620, dtype: float64

# %%
df['hours'] = df['time'].dt.hour

# %%
df['hours']
# Out:
# 0        11.0
# 1        11.0
# 2        12.0
# 3        12.0
# 4        12.0
#          ...
# 48615     NaN
# 48616     NaN
# 48617     NaN
# 48618     NaN
# 48619     NaN
# Name: hours, Length: 48620, dtype: float64

# %%
hourly_sales = df.groupby('hours')['sales'].sum().reset_index()
hourly_sales
# Out:
#     hours   sales
# 0     9.0    0.00
# 1    10.0    0.00
# 2    11.0   87.75
# 3    12.0  280.70
# 4    13.0  211.00
# 5    14.0  158.00
# 6    15.0  182.50
# 7    16.0  101.00
# 8    17.0  161.35
# 9    18.0  140.00
# 10   19.0   99.00
# 11   20.0   82.50
# 12   21.0   37.25
# 13   22.0   49.75
# 14   23.0    0.00

# %%
peak_hour = hourly_sales.loc[hourly_sales['sales'].idxmax()]

peak_hour
print(f"peak hour: {peak_hour['hours']}:00 with ${peak_hour['sales']:.2f} in sales")
# Out:
# peak hour: 12.0:00 with $280.70 in sales

# %%
plt.figure(figsize=(10,6))
plt.bar(hourly_sales['hours'],hourly_sales['sales'])
plt.xlabel('hours')
plt.ylabel('sales')
plt.title('hourly_sales')
plt.show()

# %%
peak_hour = hourly_sales.loc[hourly_sales['sales'].idxmax()]

peak_hour
print(f"peak hour: {peak_hour['hours']}:00 with ${peak_hour['sales']:.2f} in sales")
# Out:
# peak hour: 12.0:00 with $280.70 in sales

# %% [markdown]
# ### 7
# ## Total sales made on each day of the week

# %%
df['DayOfWeek'] = df['date'].dt.day_name()
df['DayOfWeek']
# Out:
# 0        Thursday
# 1        Thursday
# 2        Thursday
# 3        Thursday
# 4        Thursday
#            ...
# 48615         NaN
# 48616         NaN
# 48617         NaN
# 48618         NaN
# 48619         NaN
# Name: DayOfWeek, Length: 48620, dtype: object

# %%
daily_sales = df.groupby('DayOfWeek')['sales'].sum().reset_index()

daily_sales
# Out:
#    DayOfWeek    sales
# 0     Friday   432.45
# 1     Monday     0.00
# 2   Saturday     0.00
# 3     Sunday     0.00
# 4   Thursday  1158.35
# 5    Tuesday     0.00
# 6  Wednesday     0.00

# %%
plt.figure(figsize=(10,6))
plt.bar(daily_sales['DayOfWeek'],daily_sales['sales'])
plt.xlabel('Day Of Week')
plt.ylabel('sales')
plt.title('Tota sales of week')
plt.show()

# %% [markdown]
# ### 8
# ### Top 5 Best selling pizzas

# %%
top_best_selling_pizzas = df.groupby('name')['quantity'].sum().nlargest(5).reset_index()
top_best_selling_pizzas
# Out:
#                          name  quantity
# 0                        name     49542
# 1  The Barbecue Chicken Pizza         1
# 2          The Big Meat Pizza         1
# 3        The Brie Carre Pizza         1
# 4         The Calabrese Pizza         1

# %%
best_selling_pizzas.loc[best_selling_pizzas['quantity'].idxmax()]
# Out:
# name         name
# quantity    49542
# Name: 32, dtype: object

# %% [markdown]
# ## 9
# ### SALES Made in each month

# %%
Monthly_sales = df.groupby(df['date'].dt.to_period('M'))['sales'].sum().reset_index()
Monthly_sales
# Out:
#        date   sales
# 0   2015-01  1590.8
# 1   2015-02     0.0
# 2   2015-03     0.0
# 3   2015-04     0.0
# 4   2015-05     0.0
# 5   2015-06     0.0
# 6   2015-07     0.0
# 7   2015-08     0.0
# 8   2015-09     0.0
# 9   2015-10     0.0
# 10  2015-11     0.0
# 11  2015-12     0.0

# %%
df.head()
# Out:
#                                             order_id       date  \
# 0  <bound method Series.reset_index of 0        <... 2015-01-01
# 1  <bound method Series.reset_index of 0        <... 2015-01-01
# 2  <bound method Series.reset_index of 0        <... 2015-01-01
# 3  <bound method Series.reset_index of 0        <... 2015-01-01
# 4  <bound method Series.reset_index of 0        <... 2015-01-01
#
#                  time  order_details_id       pizza_id  quantity  \
# 0 2025-05-12 11:38:36                 1     hawaiian_m         1
# 1 2025-05-12 11:57:40                 2  classic_dlx_m         1
# 2 2025-05-12 12:12:28                 3  five_cheese_l         1
# 3 2025-05-12 12:16:31                 4    ital_supr_l         1
# 4 2025-05-12 12:21:30                 5     mexicana_m         1
#
#   pizza_type_id size  price                          name category  \
# 0       bbq_ckn    S  12.75    The Barbecue Chicken Pizza  Chicken
# ...

# %%
df.head()
# Out:
#                                             order_id       date  \
# 0  <bound method Series.reset_index of 0        <... 2015-01-01
# 1  <bound method Series.reset_index of 0        <... 2015-01-01
# 2  <bound method Series.reset_index of 0        <... 2015-01-01
# 3  <bound method Series.reset_index of 0        <... 2015-01-01
# 4  <bound method Series.reset_index of 0        <... 2015-01-01
#
#                  time  order_details_id       pizza_id  quantity  \
# 0 2025-05-12 11:38:36                 1     hawaiian_m         1
# 1 2025-05-12 11:57:40                 2  classic_dlx_m         1
# 2 2025-05-12 12:12:28                 3  five_cheese_l         1
# 3 2025-05-12 12:16:31                 4    ital_supr_l         1
# 4 2025-05-12 12:21:30                 5     mexicana_m         1
#
#   pizza_type_id size  price                          name category  \
# 0       bbq_ckn    S  12.75    The Barbecue Chicken Pizza  Chicken
# ...
